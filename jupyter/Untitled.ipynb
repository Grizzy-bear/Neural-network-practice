# %%
from skimage import data
# import malotlib.pyplot as plt
import matplotlib.pyplot as plt
cat = data.chelsea()
reddish = cat[:,:,0]>160
cat[reddish] = [0,225,0]

# %%
# plt.imshow(cat)
plt.show(cat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-c5ba1d23660e> in <module>()
#       1 # plt.imshow(cat)
# ----> 2 plt.show(cat)
#
# D:\application\anaconde\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     251     """
#     252     global _show
# --> 253     return _show(*args, **kw)
#     254
#     255
#
# D:\application\anaconde\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39         # only call close('all') if any to close
#      40         # close triggers gc.collect, which can be slow
# ---> 41         if close and Gcf.get_all_fig_managers():
#      42             matplotlib.pyplot.close('all')
#      43
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
